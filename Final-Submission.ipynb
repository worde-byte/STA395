# %%
#Training efnet

# %%
path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'
json_path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\annotations'
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torch.nn import functional
import json
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import OneHotEncoder
from pandas import get_dummies

bsize=256

img_names = os.listdir(path)
img_names = [k for k in img_names if 'npy' not in k]
i=0
from sklearn.model_selection import train_test_split
train, test = train_test_split(img_names, test_size=0.8, random_state=5)

images = np.empty(shape = (bsize, 3, 256, 256))
labels = np.chararray(bsize, itemsize=20)

# %%
train_y = train.copy()
train_X = train.copy()
for i in range(len(train)):
    train_X[i] = path + '\\' + img_names[i]
    train_y[i] = json_path + '\\' + img_names[i]
    train_y[i] = train_y[i].replace(train_y[i][len(train_y[i]) - 3:], 'json')

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

# %%
class MyDataset(Dataset):
    def __init__(self, image_paths, label_paths, transform=None):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        image = Image.open(self.image_paths[index])
        f = open(self.label_paths[index])
        data = json.load(f)
        t = data['chart-type']
        #print(t)
        if (t=='scatter'):
            label = 0
        elif (t=='vertical_bar'):
            label = 1
        elif (t=='dot'):
            label = 2
        elif (t=='horizontal_bar'):
            label = 3
        else:
            label = 4
        f.close()
        
        if self.transform:
            image = self.transform(image)
            #label = self.transform(label)
            
        return image, label

# Define the transform to resize and normalize the images
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create a dataset from the image and label file paths
dataset = MyDataset(train_X, train_y, transform=transform)

# Create a dataloader to load the data in batches
batch_size = 256
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
efnet_weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT
efnet_model = torchvision.models.efficientnet_b0(weights = efnet_weights)
## Loop through each parameter and set `requires_grad` to false
for param in efnet_model.features.parameters():
    param.requires_grad = False

## Replace the "classifier" layer with one for our application
efnet_model.classifier = torch.nn.Sequential( 
    torch.nn.Linear(in_features=1280, out_features=5, bias=True))

# %%
from torch import nn
epochs = 25
lrate = 0.1
cost_fn = nn.NLLLoss()
net = efnet_model
optimizer = torch.optim.Adam(net.parameters(), lr=lrate)
track_cost = np.zeros(epochs)

for epoch in range(epochs):
    cur_cost = 0.0
    correct = 0.0
    
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        inputs = inputs.reshape(inputs.size())
        outputs = net(inputs)
        #print(labels)
        
        cost = cost_fn(outputs.log_softmax(dim=1), labels)
        cost.backward()
        optimizer.step()
        cur_cost += cost.item()
        
    track_cost[epoch] = cur_cost
    print(f"Epoch: {epoch} Cost: {cur_cost}")
# Out:
# Epoch: 0 Cost: 39.5488263964653
# Epoch: 1 Cost: 7.533521764911711
# Epoch: 2 Cost: 4.301999458228238
# Epoch: 3 Cost: 3.3844067930913297
# Epoch: 4 Cost: 2.8492325553670526
# Epoch: 5 Cost: 2.96597113556345
# Epoch: 6 Cost: 2.404236297123134
# Epoch: 7 Cost: 5.314476940373424
# Epoch: 8 Cost: 3.794408117397694
# Epoch: 9 Cost: 2.38752241923612
# Epoch: 10 Cost: 3.368675093719503
# Epoch: 11 Cost: 1.966493472307775
# Epoch: 12 Cost: 1.949145299353404
# Epoch: 13 Cost: 2.5221488677289017
# Epoch: 14 Cost: 4.437725413765293
# Epoch: 15 Cost: 3.990123131755837
# Epoch: 16 Cost: 3.8374299549952866
# Epoch: 17 Cost: 3.0466303015527956
# Epoch: 18 Cost: 2.5983421664641355
# Epoch: 19 Cost: 2.63179542225771
# Epoch: 20 Cost: 2.8659646486128167
# Epoch: 21 Cost: 3.504437810310833
# Epoch: 22 Cost: 2.5251515382660727
# Epoch: 23 Cost: 3.4120748160676158
# Epoch: 24 Cost: 5.052723744075408

# %%
#ADD TEST CODE TO MAKE SURE IT WORKS
test_y = test.copy()
test_X = test.copy()
i=0
for i in range(len(test)):
    test_X[i] = path + '\\' + img_names[i]
    test_y[i] = json_path + '\\' + img_names[i]
    test_y[i] = test_y[i].replace(test_y[i][len(test_y[i]) - 3:], 'json')

# %%
dataset = MyDataset(test_X, test_y, transform=transform)

# Create a dataloader to load the data in batches
batch_size = 256
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
# set model to evaluation mode
net.eval()

# iterate through test data and generate predictions
with torch.no_grad():
    predicted = []
    actual = []
    for data in test_loader:
        inputs, labels = data
        outputs = net(inputs)
        _, pred = torch.max(outputs.data, 1)
        predicted.append(pred.numpy())
        actual.append(labels.numpy())
        #print(pred)
        #print(labels)
        #if (pred != labels):
            #print(inputs)

# concatenate predicted and actual labels
predicted = np.concatenate(predicted)
actual = np.concatenate(actual)

# compute accuracy
accuracy = np.mean(predicted == actual)
print(accuracy)
# Out:
# 0.9930392989579665

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(actual, predicted)

# %%
#CNN MODEL

# %%
from torch import nn

class my_net(nn.Module):
    
    ## Constructor commands
    def __init__(self):
        super(my_net, self).__init__()
        
        ## Define architecture
        self.conv_stack = nn.Sequential(
            nn.Conv2d(3,10,4,2),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(10,30,2,1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Flatten(),
            nn.Linear(28830, 250),
            nn.ReLU(),
            nn.Linear(250, 5)
        )
    
    ## Function to generate predictions
    def forward(self, x):
        scores = self.conv_stack(x)
        return scores

# %%
## Hyperparms
#epochs = 300
lrate = 0.025
bsize = 100

## For reproduction purposes 
torch.manual_seed(7)

## Cost Function
cost_fn = nn.CrossEntropyLoss()

## Intialize the model
net = my_net()

## Optimizer (Stochastic Gradient Descent)
optimizer = torch.optim.SGD(net.parameters(), lr=lrate)

# %%
img_names = os.listdir(path)
img_names = [k for k in img_names if 'npy' not in k]
i=0
from sklearn.model_selection import train_test_split
train, test = train_test_split(img_names, test_size=0.9, random_state=5)

images = np.empty(shape = (bsize, 3, 256, 256))
labels = np.chararray(bsize, itemsize=20)

# %%
train_y = train.copy()
train_X = train.copy()
for i in range(len(train)):
    train_X[i] = path + '\\' + img_names[i]
    train_y[i] = json_path + '\\' + img_names[i]
    train_y[i] = train_y[i].replace(train_y[i][len(train_y[i]) - 3:], 'json')

# %%
class MyDataset(Dataset):
    def __init__(self, image_paths, label_paths, transform=None):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        image = Image.open(self.image_paths[index])
        f = open(self.label_paths[index])
        data = json.load(f)
        t = data['chart-type']
        #print(t)
        if (t=='scatter'):
            label = 0
        elif (t=='vertical_bar'):
            label = 1
        elif (t=='dot'):
            label = 2
        elif (t=='horizontal_bar'):
            label = 3
        else:
            label = 4
        f.close()
        
        if self.transform:
            image = self.transform(image)
            #label = self.transform(label)
            
        return image, label

# Define the transform to resize and normalize the images
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create a dataset from the image and label file paths
dataset = MyDataset(train_X, train_y, transform=transform)

# Create a dataloader to load the data in batches
batch_size = 256
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
## Initial values for cost tracking
epochs = 25
track_cost = np.zeros(epochs)
cur_cost = 0.0

## Loop through the data
for epoch in range(epochs):
    
    cur_cost = 0.0
    correct = 0.0
    
    ## train_loader is iterable and numbers knows the batch
    for i, data in enumerate(train_loader, 0):
        
        ## The input tensor and labels tensor for the current batch
        inputs, labels = data
        
        ## Clear the gradient from the previous batch
        optimizer.zero_grad()
        
        ## Provide the input tensor into the network to get outputs
        outputs = net(inputs)
        
        ## Calculate the cost for the current batch
        ## nn.Softmax is used because net outputs prediction scores and our cost function expects probabilities and labels
        cost = cost_fn(nn.Softmax(dim=1)(outputs), labels)
        
        ## Calculate the gradient
        cost.backward()
        
        ## Update the model parameters using the gradient
        optimizer.step()
        
        ## Track the current cost (accumulating across batches)
        cur_cost += cost.item()
    
    ## Store the accumulated cost at each epoch
    track_cost[epoch] = cur_cost
    print(f"Epoch: {epoch} Cost: {cur_cost}") ## Uncomment this if you want printed updates
# Out:
# Epoch: 0 Cost: 36.82322072982788
# Epoch: 1 Cost: 35.413936138153076
# Epoch: 2 Cost: 35.11401641368866
# Epoch: 3 Cost: 34.81449770927429
# Epoch: 4 Cost: 34.279321908950806
# Epoch: 5 Cost: 33.7255380153656
# Epoch: 6 Cost: 33.02483820915222
# Epoch: 7 Cost: 32.30742621421814
# Epoch: 8 Cost: 31.438665747642517
# Epoch: 9 Cost: 30.734573364257812
# Epoch: 10 Cost: 30.329834938049316
# Epoch: 11 Cost: 30.017485976219177
# Epoch: 12 Cost: 29.857784152030945
# Epoch: 13 Cost: 29.69551432132721
# Epoch: 14 Cost: 29.565458297729492
# Epoch: 15 Cost: 29.643287181854248
# Epoch: 16 Cost: 29.48308801651001
# Epoch: 17 Cost: 29.325425386428833
# Epoch: 18 Cost: 29.32014036178589
# Epoch: 19 Cost: 29.26742708683014
# Epoch: 20 Cost: 29.280171632766724
# Epoch: 21 Cost: 29.222187399864197
# Epoch: 22 Cost: 29.133085131645203
# Epoch: 23 Cost: 29.132294535636902
# Epoch: 24 Cost: 29.086031317710876

# %%
import matplotlib.pyplot as plt
plt.plot(np.linspace(0, epochs, epochs), track_cost)
plt.show()

# %%
#ADD TEST CODE TO MAKE SURE IT WORKS
test_y = test.copy()
test_X = test.copy()
i=0
for i in range(len(test)):
    test_X[i] = path + '\\' + img_names[i]
    test_y[i] = json_path + '\\' + img_names[i]
    test_y[i] = test_y[i].replace(test_y[i][len(test_y[i]) - 3:], 'json')

# %%
dataset = MyDataset(test_X, test_y, transform=transform)

# Create a dataloader to load the data in batches
batch_size = 256
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

## Repeat evaluation loop using the test data
correct = 0
total = 0
actual = np.empty(0, dtype=int)
predict = np.empty(0, dtype=int)
with torch.no_grad():
    for data in test_loader:
        #if (not total % 100):
            #print(total)
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        #print(labels.numpy())
        #print(predicted.numpy())
        actual = np.append(actual, labels.numpy())
        predict = np.append(predict, predicted.numpy())
        #print(actual)
        #print(predict)
        
print(correct/total)
# Out:
# 0.6943927815118314

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(actual, predict)

# %%
#Attention Model

# %%
import string
import numpy as np
import pandas as pd
from numpy import array
from pickle import load

from PIL import Image
import pickle
from collections import Counter
import matplotlib.pyplot as plt

import sys, time, os, warnings
warnings.filterwarnings("ignore")
import re

import keras
import tensorflow as tf
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu

from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import add
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.preprocessing.text import Tokenizer
from keras.applications.vgg16 import VGG16, preprocess_input

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
image_path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'
dir_Flickr_text = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\text'
jpgs = os.listdir(image_path)

print("Total Images in Dataset = {}".format(len(jpgs)))
ann = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\annotations'
# Out:
# Total Images in Dataset = 120338

# %%
import json
image_path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'
l = os.listdir(image_path)
datas = []
result = ""
i=0

for filename in l:
    file_name = "info.txt"
    #print(file_name)
    if filename.endswith('.jpg'):
        info = []
        image_path = os.path.join(filename)
        txt_path = os.path.join(dir_Flickr_text, "info.txt")
        j = ann + '\\' + filename
        j = j[:-3] + 'json'
        with open(j, encoding="utf-8") as f:
            data = json.load(f)
            #print(data)
        f.close()
        result += image_path + "#" + str(i) + "\t"
        # Create the file in the specified directory and write the text to it
        #print(data)
        #file_text = data['text'][0]['text']
        file_text = data['chart-type'] + " " + data['chart-type'] + "a" + " " + data['chart-type'] + "b" + " " + data['chart-type'] + "c"
        #print(file_text)
        result += file_text
        result = result + "\n"
        i+=1
with open(txt_path, 'w', encoding="utf-8") as f:
    f.write(result)
#datas.append({'image_path': image_path, 'label': txt_path})

# %%
file = open(os.path.join(dir_Flickr_text, "info.txt"),'r')
text = file.read()
file.close()

datatxt = []
for line in text.split('\n'):
   col = line.split('\t')
   if len(col) == 1:
       continue
   w = col[0].split("#")
   datatxt.append(w + [col[1].lower()])

data = pd.DataFrame(datatxt,columns=["filename","index","caption"])
data = data.reindex(columns =['index','filename','caption'])
data = data[data.filename != '2258277193_586949ec62.jpg.1']
uni_filenames = np.unique(data.filename.values)

data.head()
# Out:
#   index          filename                             caption
# 0     0  0003a50817cf.jpg              line linea lineb linec
# 1     1  0005413054c9.jpg              line linea lineb linec
# 2     2  0005e64fdc6e.jpg  scatter scattera scatterb scatterc
# 3     3  000614d3eab6.jpg              line linea lineb linec
# 4     4  000631f33080.jpg  scatter scattera scatterb scatterc

# %%
npic = 5
npix = 224
target_size = (npix,npix,3)
count = 1
image_path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'

fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[10:14]:
   filename = image_path + '\\' + jpgfnm
   captions = list(data["caption"].loc[data["filename"]==jpgfnm].values)
   image_load = load_img(filename, target_size=target_size)
   ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
   ax.imshow(image_load)
   count += 1

   ax = fig.add_subplot(npic,2,count)
   plt.axis('off')
   ax.plot()
   ax.set_xlim(0,1)
   ax.set_ylim(0,len(captions))
   for i, caption in enumerate(captions):
       ax.text(0,i,caption,fontsize=20)
   count += 1
plt.show()

# %%
vocabulary = []
for txt in data.caption.values:
   vocabulary.extend(txt.split())
print('Vocabulary Size: %d' % len(set(vocabulary)))
# Out:
# Vocabulary Size: 20

# %%
def remove_punctuation(text_original):
   text_no_punctuation = text_original.translate(string.punctuation)
   return(text_no_punctuation)

def remove_single_character(text):
   text_len_more_than1 = ""
   for word in text.split():
       if len(word) > 1:
           text_len_more_than1 += " " + word
   return(text_len_more_than1)

def remove_numeric(text):
   text_no_numeric = ""
   for word in text.split():
       isalpha = word.isalpha()
       if isalpha:
           text_no_numeric += " " + word
   return(text_no_numeric)

def text_clean(text_original):
   text = remove_punctuation(text_original)
   text = remove_single_character(text)
   text = remove_numeric(text)
   return(text)

for i, caption in enumerate(data.caption.values):
   newcaption = text_clean(caption)
   data["caption"].iloc[i] = newcaption

clean_vocabulary = []
for txt in data.caption.values:
   clean_vocabulary.extend(txt.split())
print('Clean Vocabulary Size: %d' % len(set(clean_vocabulary)))
# Out:
# Clean Vocabulary Size: 12

# %%
PATH = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'
all_captions = []
for caption  in data["caption"].astype(str):
   caption = '<start> ' + caption+ ' <end>'
   all_captions.append(caption)

all_captions[:10]
# Out:
# ['<start>  line linea lineb linec <end>',
#  '<start>  line linea lineb linec <end>',
#  '<start>  scatter scattera scatterb scatterc <end>',
#  '<start>  line linea lineb linec <end>',
#  '<start>  scatter scattera scatterb scatterc <end>',
#  '<start>  dot dota dotb dotc <end>',
#  '<start>  dot dota dotb dotc <end>',
#  '<start>  <end>',
#  '<start>  line linea lineb linec <end>',
#  '<start>  line linea lineb linec <end>']

# %%
all_img_name_vector = []
for annot in data["filename"]:
   full_image_path = PATH + "\\" + annot
   all_img_name_vector.append(full_image_path)

all_img_name_vector[:10]
# Out:
# ['C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\0003a50817cf.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\0005413054c9.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\0005e64fdc6e.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\000614d3eab6.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\000631f33080.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\000917f5d829.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\000944919c5c.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\0011bb0573da.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\001221641993.jpg',
#  'C:\\Users\\16032\\Downloads\\benetech-making-graphs-accessible\\train\\images\\001228841945.jpg']

# %%
print(f"len(all_img_name_vector) : {len(all_img_name_vector)}")
print(f"len(all_captions) : {len(all_captions)}")
# Out:
# len(all_img_name_vector) : 60338
# len(all_captions) : 60338

# %%
def data_limiter(num,total_captions,all_img_name_vector):
    train_captions, img_name_vector = shuffle(total_captions,all_img_name_vector,random_state=1)
    train_captions = train_captions[:num]
    img_name_vector = img_name_vector[:num]
    return train_captions,img_name_vector

train_captions,img_name_vector = data_limiter(60000,all_captions,all_img_name_vector)

# %%
def load_image(image_path):
   img = tf.io.read_file(image_path)
   img = tf.image.decode_jpeg(img, channels=3)
   img = tf.image.resize(img, (224, 224))
   img = preprocess_input(img)
   return img, image_path

image_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output
image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

image_features_extract_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
encode_train = sorted(set(img_name_vector))
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(64)

# %%
# %%time
for img, path in tqdm(image_dataset):
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                             (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 938/938 [1:14:50<00:00,  4.79s/it]
# Wall time: 1h 14min 50s

# %%
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                 oov_token="<unk>",
                                                 filters='!"#$%&()*+.,-/:;=?@[\]^`{|}~ ')

tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

train_seqs = tokenizer.texts_to_sequences(train_captions)
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
train_captions[:3]
# Out:
# ['<start>  line linea lineb linec <end>',
#  '<start>  scatter scattera scatterb scatterc <end>',
#  '<start>  line linea lineb linec <end>']

# %%
train_seqs[:3]
# Out:
# [[2, 4, 5, 6, 7, 3], [2, 8, 9, 10, 11, 3], [2, 4, 5, 6, 7, 3]]

# %%
def calc_max_length(tensor):
   return max(len(t) for t in tensor)
max_length = calc_max_length(train_seqs)

def calc_min_length(tensor):
   return min(len(t) for t in tensor)
min_length = calc_min_length(train_seqs)

print('Max Length of any caption : Min Length of any caption = '+ str(max_length) +" : "+str(min_length))
# Out:
# Max Length of any caption : Min Length of any caption = 6 : 2

# %%
img_name_train, img_name_val, cap_train, cap_val = train_test_split(img_name_vector,cap_vector, test_size=0.5, random_state=0)

# %%
BATCH_SIZE = 24
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = len(tokenizer.word_index) + 1
num_steps = len(img_name_train) // BATCH_SIZE
features_shape = 512
attention_features_shape = 49

# %%
def map_func(img_name, cap):
 img_tensor = np.load(img_name.decode('utf-8')+'.npy')
 return img_tensor, cap
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
        map_func, [item1, item2], [tf.float32, tf.int32]),
         num_parallel_calls=tf.data.experimental.AUTOTUNE)

dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class VGG16_Encoder(tf.keras.Model):
   # This encoder passes the features through a Fully connected layer
   def __init__(self, embedding_dim):
       super(VGG16_Encoder, self).__init__()
       # shape after fc == (batch_size, 49, embedding_dim)
       self.fc = tf.keras.layers.Dense(embedding_dim)
       self.dropout = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)

   def call(self, x):
       #x= self.dropout(x)
       x = self.fc(x)
       x = tf.nn.relu(x)
       return x

# %%
def rnn_type(units):
   if tf.test.is_gpu_available():
       return tf.compat.v1.keras.layers.CuDNNLSTM(units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
   else:
       return tf.keras.layers.GRU(units,
                                  return_sequences=True,
                                  return_state=True,
                                  recurrent_activation='sigmoid',
                                  recurrent_initializer='glorot_uniform')

# %%
class Rnn_Local_Decoder(tf.keras.Model):
 def __init__(self, embedding_dim, units, vocab_size):
   super(Rnn_Local_Decoder, self).__init__()
   self.units = units
   self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
   self.gru = tf.keras.layers.GRU(self.units,
                                  return_sequences=True,
                                  return_state=True,
                                  recurrent_initializer='glorot_uniform')
  
   self.fc1 = tf.keras.layers.Dense(self.units)

   self.dropout = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)
   self.batchnormalization = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros', moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, beta_constraint=None, gamma_constraint=None)

   self.fc2 = tf.keras.layers.Dense(vocab_size)

   # Implementing Attention Mechanism
   self.Uattn = tf.keras.layers.Dense(units)
   self.Wattn = tf.keras.layers.Dense(units)
   self.Vattn = tf.keras.layers.Dense(1)

 def call(self, x, features, hidden):
   # features shape ==> (64,49,256) ==> Output from ENCODER
   # hidden shape == (batch_size, hidden_size) ==>(64,512)
   # hidden_with_time_axis shape == (batch_size, 1, hidden_size) ==> (64,1,512)

   hidden_with_time_axis = tf.expand_dims(hidden, 1)

   # score shape == (64, 49, 1)
   # Attention Function
   '''e(ij) = f(s(t-1),h(j))'''
   ''' e(ij) = Vattn(T)*tanh(Uattn * h(j) + Wattn * s(t))'''

   score = self.Vattn(tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis)))

   # self.Uattn(features) : (64,49,512)
   # self.Wattn(hidden_with_time_axis) : (64,1,512)
   # tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis)) : (64,49,512)
   # self.Vattn(tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis))) : (64,49,1) ==> score

   # you get 1 at the last axis because you are applying score to self.Vattn
   # Then find Probability using Softmax
   '''attention_weights(alpha(ij)) = softmax(e(ij))'''

   attention_weights = tf.nn.softmax(score, axis=1)

   # attention_weights shape == (64, 49, 1)
   # Give weights to the different pixels in the image
   ''' C(t) = Summation(j=1 to T) (attention_weights * VGG-16 features) '''

   context_vector = attention_weights * features
   context_vector = tf.reduce_sum(context_vector, axis=1)

   # Context Vector(64,256) = AttentionWeights(64,49,1) * features(64,49,256)
   # context_vector shape after sum == (64, 256)
   # x shape after passing through embedding == (64, 1, 256)

   x = self.embedding(x)
   # x shape after concatenation == (64, 1,  512)

   x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
   # passing the concatenated vector to the GRU

   output, state = self.gru(x)
   # shape == (batch_size, max_length, hidden_size)

   x = self.fc1(output)
   # x shape == (batch_size * max_length, hidden_size)

   x = tf.reshape(x, (-1, x.shape[2]))

   # Adding Dropout and BatchNorm Layers
   x= self.dropout(x)
   x= self.batchnormalization(x)

   # output shape == (64 * 512)
   x = self.fc2(x)

   # shape : (64 * 8329(vocab))
   return x, state, attention_weights

 def reset_state(self, batch_size):
   return tf.zeros((batch_size, self.units))


encoder = VGG16_Encoder(embedding_dim)
decoder = Rnn_Local_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
   from_logits=True, reduction='none')

def loss_function(real, pred):
 mask = tf.math.logical_not(tf.math.equal(real, 0))
 loss_ = loss_object(real, pred)
 mask = tf.cast(mask, dtype=loss_.dtype)
 loss_ *= mask

 return tf.reduce_mean(loss_)

# %%
loss_plot = []

@tf.function
def train_step(img_tensor, target):
 loss = 0
 # initializing the hidden state for each batch
 # because the captions are not related from image to image

 hidden = decoder.reset_state(batch_size=target.shape[0])
 dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * BATCH_SIZE, 1)

 with tf.GradientTape() as tape:
     features = encoder(img_tensor)
     for i in range(1, target.shape[1]):
         # passing the features through the decoder
         predictions, hidden, _ = decoder(dec_input, features, hidden)
         loss += loss_function(target[:, i], predictions)

         # using teacher forcing
         dec_input = tf.expand_dims(target[:, i], 1)

 total_loss = (loss / int(target.shape[1]))
 trainable_variables = encoder.trainable_variables + decoder.trainable_variables
 gradients = tape.gradient(loss, trainable_variables)
 optimizer.apply_gradients(zip(gradients, trainable_variables))

 return loss, total_loss

# %%
EPOCHS = 50
start_epoch = 0
for epoch in range(start_epoch, EPOCHS):
   start = time.time()
   total_loss = 0

   for (batch, (img_tensor, target)) in enumerate(dataset):
       batch_loss, t_loss = train_step(img_tensor, target)
       total_loss += t_loss

       if batch % 100 == 0:
           print ('Epoch {} Batch {} Loss {:.4f}'.format(
             epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
   # storing the epoch end loss value to plot later
   loss_plot.append(total_loss / num_steps)

   print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                        total_loss/num_steps))

   print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.5107
# Epoch 1 Batch 100 Loss 0.0024
# Epoch 1 Batch 200 Loss 0.0034
# Epoch 1 Batch 300 Loss 0.0084
# Epoch 1 Batch 400 Loss 0.0009
# Epoch 1 Batch 500 Loss 0.0280
# Epoch 1 Batch 600 Loss 0.0036
# Epoch 1 Batch 700 Loss 0.0007
# Epoch 1 Batch 800 Loss 0.0001
# Epoch 1 Batch 900 Loss 0.0043
# Epoch 1 Batch 1000 Loss 0.0007
# Epoch 1 Batch 1100 Loss 0.0001
# Epoch 1 Batch 1200 Loss 0.0001
# Epoch 1 Loss 0.038081
# Time taken for 1 epoch 97.22527933120728 sec
#
# Epoch 2 Batch 0 Loss 0.0001
# Epoch 2 Batch 100 Loss 0.0001
# Epoch 2 Batch 200 Loss 0.0416
# Epoch 2 Batch 300 Loss 0.0056
# Epoch 2 Batch 400 Loss 0.0000
# Epoch 2 Batch 500 Loss 0.0012
# Epoch 2 Batch 600 Loss 0.0000
# Epoch 2 Batch 700 Loss 0.0001
# Epoch 2 Batch 800 Loss 0.0017
# Epoch 2 Batch 900 Loss 0.0007
# Epoch 2 Batch 1000 Loss 0.0001
# Epoch 2 Batch 1100 Loss 0.0001
# Epoch 2 Batch 1200 Loss 0.0001
# Epoch 2 Loss 0.002891
# Time taken for 1 epoch 79.50963544845581 sec
#
# Epoch 3 Batch 0 Loss 0.0001
# Epoch 3 Batch 100 Loss 0.0171
# Epoch 3 Batch 200 Loss 0.0003
# Epoch 3 Batch 300 Loss 0.0003
# Epoch 3 Batch 400 Loss 0.0001
# Epoch 3 Batch 500 Loss 0.0000
# Epoch 3 Batch 600 Loss 0.0000
# Epoch 3 Batch 700 Loss 0.0001
# Epoch 3 Batch 800 Loss 0.0000
# Epoch 3 Batch 900 Loss 0.0009
# Epoch 3 Batch 1000 Loss 0.0001
# Epoch 3 Batch 1100 Loss 0.0000
# Epoch 3 Batch 1200 Loss 0.0001
# Epoch 3 Loss 0.003223
# Time taken for 1 epoch 80.71561932563782 sec
#
# Epoch 4 Batch 0 Loss 0.0003
# Epoch 4 Batch 100 Loss 0.0000
# Epoch 4 Batch 200 Loss 0.0001
# Epoch 4 Batch 300 Loss 0.0000
# Epoch 4 Batch 400 Loss 0.0002
# Epoch 4 Batch 500 Loss 0.0005
# Epoch 4 Batch 600 Loss 0.0000
# Epoch 4 Batch 700 Loss 0.0011
# Epoch 4 Batch 800 Loss 0.0000
# Epoch 4 Batch 900 Loss 0.0001
# Epoch 4 Batch 1000 Loss 0.0005
# Epoch 4 Batch 1100 Loss 0.0001
# Epoch 4 Batch 1200 Loss 0.0000
# Epoch 4 Loss 0.001949
# Time taken for 1 epoch 80.61536860466003 sec
#
# Epoch 5 Batch 0 Loss 0.0000
# Epoch 5 Batch 100 Loss 0.0024
# Epoch 5 Batch 200 Loss 0.0003
# Epoch 5 Batch 300 Loss 0.0001
# Epoch 5 Batch 400 Loss 0.0002
# Epoch 5 Batch 500 Loss 0.0000
# Epoch 5 Batch 600 Loss 0.0007
# Epoch 5 Batch 700 Loss 0.0005
# Epoch 5 Batch 800 Loss 0.0000
# Epoch 5 Batch 900 Loss 0.0000
# Epoch 5 Batch 1000 Loss 0.0001
# Epoch 5 Batch 1100 Loss 0.0000
# Epoch 5 Batch 1200 Loss 0.0000
# Epoch 5 Loss 0.002251
# Time taken for 1 epoch 80.53209614753723 sec
#
# Epoch 6 Batch 0 Loss 0.0000
# Epoch 6 Batch 100 Loss 0.0000
# Epoch 6 Batch 200 Loss 0.0464
# Epoch 6 Batch 300 Loss 0.0000
# Epoch 6 Batch 400 Loss 0.0003
# Epoch 6 Batch 500 Loss 0.0001
# Epoch 6 Batch 600 Loss 0.0000
# Epoch 6 Batch 700 Loss 0.0000
# Epoch 6 Batch 800 Loss 0.0002
# Epoch 6 Batch 900 Loss 0.0003
# Epoch 6 Batch 1000 Loss 0.0001
# Epoch 6 Batch 1100 Loss 0.0001
# Epoch 6 Batch 1200 Loss 0.0002
# Epoch 6 Loss 0.002403
# Time taken for 1 epoch 80.68298172950745 sec
#
# Epoch 7 Batch 0 Loss 0.0000
# Epoch 7 Batch 100 Loss 0.0000
# Epoch 7 Batch 200 Loss 0.0000
# Epoch 7 Batch 300 Loss 0.0001
# Epoch 7 Batch 400 Loss 0.0000
# Epoch 7 Batch 500 Loss 0.0018
# Epoch 7 Batch 600 Loss 0.0000
# Epoch 7 Batch 700 Loss 0.0003
# Epoch 7 Batch 800 Loss 0.0020
# Epoch 7 Batch 900 Loss 0.0000
# Epoch 7 Batch 1000 Loss 0.0009
# Epoch 7 Batch 1100 Loss 0.0001
# Epoch 7 Batch 1200 Loss 0.0000
# Epoch 7 Loss 0.001413
# Time taken for 1 epoch 80.7339346408844 sec
#
# Epoch 8 Batch 0 Loss 0.0089
# Epoch 8 Batch 100 Loss 0.0000
# Epoch 8 Batch 200 Loss 0.0001
# Epoch 8 Batch 300 Loss 0.0002
# Epoch 8 Batch 400 Loss 0.0000
# Epoch 8 Batch 500 Loss 0.0000
# Epoch 8 Batch 600 Loss 0.0003
# Epoch 8 Batch 700 Loss 0.0000
# Epoch 8 Batch 800 Loss 0.0000
# Epoch 8 Batch 900 Loss 0.0001
# Epoch 8 Batch 1000 Loss 0.0007
# Epoch 8 Batch 1100 Loss 0.0000
# Epoch 8 Batch 1200 Loss 0.0000
# Epoch 8 Loss 0.001441
# Time taken for 1 epoch 81.00045537948608 sec
#
# Epoch 9 Batch 0 Loss 0.0001
# Epoch 9 Batch 100 Loss 0.0000
# Epoch 9 Batch 200 Loss 0.0005
# Epoch 9 Batch 300 Loss 0.0000
# Epoch 9 Batch 400 Loss 0.0000
# Epoch 9 Batch 500 Loss 0.0000
# Epoch 9 Batch 600 Loss 0.0001
# Epoch 9 Batch 700 Loss 0.0000
# Epoch 9 Batch 800 Loss 0.0000
# Epoch 9 Batch 900 Loss 0.0000
# Epoch 9 Batch 1000 Loss 0.0000
# Epoch 9 Batch 1100 Loss 0.0000
# Epoch 9 Batch 1200 Loss 0.0000
# Epoch 9 Loss 0.000933
# Time taken for 1 epoch 80.51432418823242 sec
#
# Epoch 10 Batch 0 Loss 0.0000
# Epoch 10 Batch 100 Loss 0.0003
# Epoch 10 Batch 200 Loss 0.0206
# Epoch 10 Batch 300 Loss 0.0000
# Epoch 10 Batch 400 Loss 0.0000
# Epoch 10 Batch 500 Loss 0.0190
# Epoch 10 Batch 600 Loss 0.0000
# Epoch 10 Batch 700 Loss 0.0056
# Epoch 10 Batch 800 Loss 0.0043
# Epoch 10 Batch 900 Loss 0.0003
# Epoch 10 Batch 1000 Loss 0.0000
# Epoch 10 Batch 1100 Loss 0.0002
# Epoch 10 Batch 1200 Loss 0.0001
# Epoch 10 Loss 0.002524
# Time taken for 1 epoch 80.79019570350647 sec
#
# Epoch 11 Batch 0 Loss 0.0000
# Epoch 11 Batch 100 Loss 0.0000
# Epoch 11 Batch 200 Loss 0.0000
# Epoch 11 Batch 300 Loss 0.0000
# Epoch 11 Batch 400 Loss 0.0000
# Epoch 11 Batch 500 Loss 0.0000
# Epoch 11 Batch 600 Loss 0.0000
# Epoch 11 Batch 700 Loss 0.0000
# Epoch 11 Batch 800 Loss 0.0000
# Epoch 11 Batch 900 Loss 0.0188
# Epoch 11 Batch 1000 Loss 0.0015
# Epoch 11 Batch 1100 Loss 0.0003
# Epoch 11 Batch 1200 Loss 0.0000
# Epoch 11 Loss 0.001245
# Time taken for 1 epoch 80.50039052963257 sec
#
# Epoch 12 Batch 0 Loss 0.0000
# Epoch 12 Batch 100 Loss 0.0000
# Epoch 12 Batch 200 Loss 0.0023
# Epoch 12 Batch 300 Loss 0.0000
# Epoch 12 Batch 400 Loss 0.0770
# Epoch 12 Batch 500 Loss 0.0001
# Epoch 12 Batch 600 Loss 0.0001
# Epoch 12 Batch 700 Loss 0.0000
# Epoch 12 Batch 800 Loss 0.0000
# Epoch 12 Batch 900 Loss 0.0000
# Epoch 12 Batch 1000 Loss 0.0000
# Epoch 12 Batch 1100 Loss 0.0000
# Epoch 12 Batch 1200 Loss 0.0000
# Epoch 12 Loss 0.001057
# Time taken for 1 epoch 80.63657259941101 sec
#
# Epoch 13 Batch 0 Loss 0.0000
# Epoch 13 Batch 100 Loss 0.0000
# Epoch 13 Batch 200 Loss 0.0000
# Epoch 13 Batch 300 Loss 0.0000
# Epoch 13 Batch 400 Loss 0.0039
# Epoch 13 Batch 500 Loss 0.0000
# Epoch 13 Batch 600 Loss 0.0002
# Epoch 13 Batch 700 Loss 0.0000
# Epoch 13 Batch 800 Loss 0.0001
# Epoch 13 Batch 900 Loss 0.0000
# Epoch 13 Batch 1000 Loss 0.0001
# Epoch 13 Batch 1100 Loss 0.0000
# Epoch 13 Batch 1200 Loss 0.0000
# Epoch 13 Loss 0.000961
# Time taken for 1 epoch 81.01594233512878 sec
#
# Epoch 14 Batch 0 Loss 0.0000
# Epoch 14 Batch 100 Loss 0.0000
# Epoch 14 Batch 200 Loss 0.0000
# Epoch 14 Batch 300 Loss 0.0000
# Epoch 14 Batch 400 Loss 0.0040
# Epoch 14 Batch 500 Loss 0.0000
# Epoch 14 Batch 600 Loss 0.0001
# Epoch 14 Batch 700 Loss 0.0001
# Epoch 14 Batch 800 Loss 0.0000
# Epoch 14 Batch 900 Loss 0.0000
# Epoch 14 Batch 1000 Loss 0.0001
# Epoch 14 Batch 1100 Loss 0.0000
# Epoch 14 Batch 1200 Loss 0.0000
# Epoch 14 Loss 0.001828
# Time taken for 1 epoch 80.83401012420654 sec
#
# Epoch 15 Batch 0 Loss 0.0000
# Epoch 15 Batch 100 Loss 0.0021
# Epoch 15 Batch 200 Loss 0.0000
# Epoch 15 Batch 300 Loss 0.0000
# Epoch 15 Batch 400 Loss 0.0001
# Epoch 15 Batch 500 Loss 0.0000
# Epoch 15 Batch 600 Loss 0.0000
# Epoch 15 Batch 700 Loss 0.0000
# Epoch 15 Batch 800 Loss 0.0000
# Epoch 15 Batch 900 Loss 0.0000
# Epoch 15 Batch 1000 Loss 0.0000
# Epoch 15 Batch 1100 Loss 0.0000
# Epoch 15 Batch 1200 Loss 0.0000
# Epoch 15 Loss 0.000944
# Time taken for 1 epoch 79.74419021606445 sec
#
# Epoch 16 Batch 0 Loss 0.0000
# Epoch 16 Batch 100 Loss 0.0000
# Epoch 16 Batch 200 Loss 0.0000
# Epoch 16 Batch 300 Loss 0.0000
# Epoch 16 Batch 400 Loss 0.0000
# Epoch 16 Batch 500 Loss 0.0000
# Epoch 16 Batch 600 Loss 0.0001
# Epoch 16 Batch 700 Loss 0.0000
# Epoch 16 Batch 800 Loss 0.0001
# Epoch 16 Batch 900 Loss 0.0000
# Epoch 16 Batch 1000 Loss 0.0001
# Epoch 16 Batch 1100 Loss 0.0001
# Epoch 16 Batch 1200 Loss 0.0000
# Epoch 16 Loss 0.001194
# Time taken for 1 epoch 80.07328605651855 sec
#
# Epoch 17 Batch 0 Loss 0.0000
# Epoch 17 Batch 100 Loss 0.0000
# Epoch 17 Batch 200 Loss 0.0000
# Epoch 17 Batch 300 Loss 0.0001
# Epoch 17 Batch 400 Loss 0.0000
# Epoch 17 Batch 500 Loss 0.0000
# Epoch 17 Batch 600 Loss 0.0000
# Epoch 17 Batch 700 Loss 0.0000
# Epoch 17 Batch 800 Loss 0.0000
# Epoch 17 Batch 900 Loss 0.0007
# Epoch 17 Batch 1000 Loss 0.0000
# Epoch 17 Batch 1100 Loss 0.0000
# Epoch 17 Batch 1200 Loss 0.0000
# Epoch 17 Loss 0.001163
# Time taken for 1 epoch 80.36317205429077 sec
#
# Epoch 18 Batch 0 Loss 0.0000
# Epoch 18 Batch 100 Loss 0.0000
# Epoch 18 Batch 200 Loss 0.0000
# Epoch 18 Batch 300 Loss 0.0000
# Epoch 18 Batch 400 Loss 0.0000
# Epoch 18 Batch 500 Loss 0.0000
# Epoch 18 Batch 600 Loss 0.0000
# Epoch 18 Batch 700 Loss 0.0003
# Epoch 18 Batch 800 Loss 0.0000
# Epoch 18 Batch 900 Loss 0.0000
# Epoch 18 Batch 1000 Loss 0.0000
# Epoch 18 Batch 1100 Loss 0.0000
# Epoch 18 Batch 1200 Loss 0.0000
# Epoch 18 Loss 0.000875
# Time taken for 1 epoch 80.00459933280945 sec
#
# Epoch 19 Batch 0 Loss 0.0000
# Epoch 19 Batch 100 Loss 0.0000
# Epoch 19 Batch 200 Loss 0.0000
# Epoch 19 Batch 300 Loss 0.0000
# Epoch 19 Batch 400 Loss 0.0005
# Epoch 19 Batch 500 Loss 0.0000
# Epoch 19 Batch 600 Loss 0.0000
# Epoch 19 Batch 700 Loss 0.0000
# Epoch 19 Batch 800 Loss 0.0001
# Epoch 19 Batch 900 Loss 0.0001
# Epoch 19 Batch 1000 Loss 0.0000
# Epoch 19 Batch 1100 Loss 0.0096
# Epoch 19 Batch 1200 Loss 0.0000
# Epoch 19 Loss 0.001106
# Time taken for 1 epoch 79.92171549797058 sec
#
# Epoch 20 Batch 0 Loss 0.0008
# Epoch 20 Batch 100 Loss 0.0000
# Epoch 20 Batch 200 Loss 0.0000
# Epoch 20 Batch 300 Loss 0.0000
# Epoch 20 Batch 400 Loss 0.0000
# Epoch 20 Batch 500 Loss 0.0000
# Epoch 20 Batch 600 Loss 0.0000
# Epoch 20 Batch 700 Loss 0.0000
# Epoch 20 Batch 800 Loss 0.0000
# Epoch 20 Batch 900 Loss 0.0000
# Epoch 20 Batch 1000 Loss 0.0000
# Epoch 20 Batch 1100 Loss 0.0000
# Epoch 20 Batch 1200 Loss 0.0000
# Epoch 20 Loss 0.000973
# Time taken for 1 epoch 79.49590539932251 sec
#
# Epoch 21 Batch 0 Loss 0.0000
# Epoch 21 Batch 100 Loss 0.0162
# Epoch 21 Batch 200 Loss 0.0000
# Epoch 21 Batch 300 Loss 0.0000
# Epoch 21 Batch 400 Loss 0.0000
# Epoch 21 Batch 500 Loss 0.0000
# Epoch 21 Batch 600 Loss 0.0000
# Epoch 21 Batch 700 Loss 0.0000
# Epoch 21 Batch 800 Loss 0.0000
# Epoch 21 Batch 900 Loss 0.0000
# Epoch 21 Batch 1000 Loss 0.0001
# Epoch 21 Batch 1100 Loss 0.0000
# Epoch 21 Batch 1200 Loss 0.0000
# Epoch 21 Loss 0.000727
# Time taken for 1 epoch 79.37851881980896 sec
#
# Epoch 22 Batch 0 Loss 0.0000
# Epoch 22 Batch 100 Loss 0.0000
# Epoch 22 Batch 200 Loss 0.0000
# Epoch 22 Batch 300 Loss 0.0000
# Epoch 22 Batch 400 Loss 0.0000
# Epoch 22 Batch 500 Loss 0.0000
# Epoch 22 Batch 600 Loss 0.0000
# Epoch 22 Batch 700 Loss 0.0000
# Epoch 22 Batch 800 Loss 0.0000
# Epoch 22 Batch 900 Loss 0.0000
# Epoch 22 Batch 1000 Loss 0.0003
# Epoch 22 Batch 1100 Loss 0.0001
# Epoch 22 Batch 1200 Loss 0.0001
# Epoch 22 Loss 0.000974
# Time taken for 1 epoch 79.13788199424744 sec
#
# Epoch 23 Batch 0 Loss 0.0000
# Epoch 23 Batch 100 Loss 0.0000
# Epoch 23 Batch 200 Loss 0.0004
# Epoch 23 Batch 300 Loss 0.0000
# Epoch 23 Batch 400 Loss 0.0003
# Epoch 23 Batch 500 Loss 0.0000
# Epoch 23 Batch 600 Loss 0.0000
# Epoch 23 Batch 700 Loss 0.0000
# Epoch 23 Batch 800 Loss 0.0000
# Epoch 23 Batch 900 Loss 0.0000
# Epoch 23 Batch 1000 Loss 0.0000
# Epoch 23 Batch 1100 Loss 0.0011
# Epoch 23 Batch 1200 Loss 0.0000
# Epoch 23 Loss 0.000943
# Time taken for 1 epoch 79.59907150268555 sec
#
# Epoch 24 Batch 0 Loss 0.0000
# Epoch 24 Batch 100 Loss 0.0000
# Epoch 24 Batch 200 Loss 0.0000
# Epoch 24 Batch 300 Loss 0.0000
# Epoch 24 Batch 400 Loss 0.0000
# Epoch 24 Batch 500 Loss 0.0000
# Epoch 24 Batch 600 Loss 0.0000
# Epoch 24 Batch 700 Loss 0.0000
# Epoch 24 Batch 800 Loss 0.0000
# Epoch 24 Batch 900 Loss 0.0000
# Epoch 24 Batch 1000 Loss 0.0000
# Epoch 24 Batch 1100 Loss 0.0000
# Epoch 24 Batch 1200 Loss 0.0000
# Epoch 24 Loss 0.000661
# Time taken for 1 epoch 80.20230650901794 sec
#
# Epoch 25 Batch 0 Loss 0.0000
# Epoch 25 Batch 100 Loss 0.0000
# Epoch 25 Batch 200 Loss 0.0001
# Epoch 25 Batch 300 Loss 0.0000
# Epoch 25 Batch 400 Loss 0.0000
# Epoch 25 Batch 500 Loss 0.0002
# Epoch 25 Batch 600 Loss 0.0000
# Epoch 25 Batch 700 Loss 0.0000
# Epoch 25 Batch 800 Loss 0.0000
# Epoch 25 Batch 900 Loss 0.0001
# Epoch 25 Batch 1000 Loss 0.0001
# Epoch 25 Batch 1100 Loss 0.0000
# Epoch 25 Batch 1200 Loss 0.0000
# Epoch 25 Loss 0.000907
# Time taken for 1 epoch 79.87051129341125 sec
#
# Epoch 26 Batch 0 Loss 0.0123
# Epoch 26 Batch 100 Loss 0.0000
# Epoch 26 Batch 200 Loss 0.0000
# Epoch 26 Batch 300 Loss 0.0001
# Epoch 26 Batch 400 Loss 0.0004
# Epoch 26 Batch 500 Loss 0.0000
# Epoch 26 Batch 600 Loss 0.0307
# Epoch 26 Batch 700 Loss 0.0000
# Epoch 26 Batch 800 Loss 0.0000
# Epoch 26 Batch 900 Loss 0.0000
# Epoch 26 Batch 1000 Loss 0.0001
# Epoch 26 Batch 1100 Loss 0.0002
# Epoch 26 Batch 1200 Loss 0.0000
# Epoch 26 Loss 0.001194
# Time taken for 1 epoch 79.25228357315063 sec
#
# Epoch 27 Batch 0 Loss 0.0000
# Epoch 27 Batch 100 Loss 0.0000
# Epoch 27 Batch 200 Loss 0.0000
# Epoch 27 Batch 300 Loss 0.0000
# Epoch 27 Batch 400 Loss 0.0000
# Epoch 27 Batch 500 Loss 0.0095
# Epoch 27 Batch 600 Loss 0.0000
# Epoch 27 Batch 700 Loss 0.0000
# Epoch 27 Batch 800 Loss 0.0000
# Epoch 27 Batch 900 Loss 0.0000
# Epoch 27 Batch 1000 Loss 0.0002
# Epoch 27 Batch 1100 Loss 0.0000
# Epoch 27 Batch 1200 Loss 0.0000
# Epoch 27 Loss 0.000688
# Time taken for 1 epoch 80.43676781654358 sec
#
# Epoch 28 Batch 0 Loss 0.0000
# Epoch 28 Batch 100 Loss 0.0000
# Epoch 28 Batch 200 Loss 0.0000
# Epoch 28 Batch 300 Loss 0.0000
# Epoch 28 Batch 400 Loss 0.0000
# Epoch 28 Batch 500 Loss 0.0001
# Epoch 28 Batch 600 Loss 0.0003
# Epoch 28 Batch 700 Loss 0.0000
# Epoch 28 Batch 800 Loss 0.0000
# Epoch 28 Batch 900 Loss 0.0000
# Epoch 28 Batch 1000 Loss 0.0000
# Epoch 28 Batch 1100 Loss 0.0000
# Epoch 28 Batch 1200 Loss 0.0000
# Epoch 28 Loss 0.000575
# Time taken for 1 epoch 79.91420221328735 sec
#
# Epoch 29 Batch 0 Loss 0.0000
# Epoch 29 Batch 100 Loss 0.0000
# Epoch 29 Batch 200 Loss 0.0000
# Epoch 29 Batch 300 Loss 0.0000
# Epoch 29 Batch 400 Loss 0.0000
# Epoch 29 Batch 500 Loss 0.0000
# Epoch 29 Batch 600 Loss 0.0000
# Epoch 29 Batch 700 Loss 0.0001
# Epoch 29 Batch 800 Loss 0.0000
# Epoch 29 Batch 900 Loss 0.0000
# Epoch 29 Batch 1000 Loss 0.0000
# Epoch 29 Batch 1100 Loss 0.0016
# Epoch 29 Batch 1200 Loss 0.0000
# Epoch 29 Loss 0.000519
# Time taken for 1 epoch 79.5278115272522 sec
#
# Epoch 30 Batch 0 Loss 0.0000
# Epoch 30 Batch 100 Loss 0.0000
# Epoch 30 Batch 200 Loss 0.0001
# Epoch 30 Batch 300 Loss 0.0000
# Epoch 30 Batch 400 Loss 0.0000
# Epoch 30 Batch 500 Loss 0.0000
# Epoch 30 Batch 600 Loss 0.0000
# Epoch 30 Batch 700 Loss 0.0000
# Epoch 30 Batch 800 Loss 0.0000
# Epoch 30 Batch 900 Loss 0.0000
# Epoch 30 Batch 1000 Loss 0.0000
# Epoch 30 Batch 1100 Loss 0.0000
# Epoch 30 Batch 1200 Loss 0.0000
# Epoch 30 Loss 0.000453
# Time taken for 1 epoch 78.94124627113342 sec
#
# Epoch 31 Batch 0 Loss 0.0002
# Epoch 31 Batch 100 Loss 0.0000
# Epoch 31 Batch 200 Loss 0.0000
# Epoch 31 Batch 300 Loss 0.0000
# Epoch 31 Batch 400 Loss 0.0000
# Epoch 31 Batch 500 Loss 0.0000
# Epoch 31 Batch 600 Loss 0.0000
# Epoch 31 Batch 700 Loss 0.0003
# Epoch 31 Batch 800 Loss 0.0000
# Epoch 31 Batch 900 Loss 0.0000
# Epoch 31 Batch 1000 Loss 0.0000
# Epoch 31 Batch 1100 Loss 0.0000
# Epoch 31 Batch 1200 Loss 0.0001
# Epoch 31 Loss 0.001103
# Time taken for 1 epoch 78.66053915023804 sec
#
# Epoch 32 Batch 0 Loss 0.0000
# Epoch 32 Batch 100 Loss 0.0000
# Epoch 32 Batch 200 Loss 0.0000
# Epoch 32 Batch 300 Loss 0.0000
# Epoch 32 Batch 400 Loss 0.0000
# Epoch 32 Batch 500 Loss 0.0000
# Epoch 32 Batch 600 Loss 0.0000
# Epoch 32 Batch 700 Loss 0.0000
# Epoch 32 Batch 800 Loss 0.0000
# Epoch 32 Batch 900 Loss 0.0092
# Epoch 32 Batch 1000 Loss 0.0002
# Epoch 32 Batch 1100 Loss 0.0001
# Epoch 32 Batch 1200 Loss 0.0000
# Epoch 32 Loss 0.000808
# Time taken for 1 epoch 78.807856798172 sec
#
# Epoch 33 Batch 0 Loss 0.0000
# Epoch 33 Batch 100 Loss 0.0000
# Epoch 33 Batch 200 Loss 0.0000
# Epoch 33 Batch 300 Loss 0.0005
# Epoch 33 Batch 400 Loss 0.0001
# Epoch 33 Batch 500 Loss 0.0000
# Epoch 33 Batch 600 Loss 0.0000
# Epoch 33 Batch 700 Loss 0.0000
# Epoch 33 Batch 800 Loss 0.0000
# Epoch 33 Batch 900 Loss 0.0000
# Epoch 33 Batch 1000 Loss 0.0001
# Epoch 33 Batch 1100 Loss 0.0000
# Epoch 33 Batch 1200 Loss 0.0000
# Epoch 33 Loss 0.000448
# Time taken for 1 epoch 78.42123675346375 sec
#
# Epoch 34 Batch 0 Loss 0.0000
# Epoch 34 Batch 100 Loss 0.0000
# Epoch 34 Batch 200 Loss 0.0000
# Epoch 34 Batch 300 Loss 0.0000
# Epoch 34 Batch 400 Loss 0.0000
# Epoch 34 Batch 500 Loss 0.0000
# Epoch 34 Batch 600 Loss 0.0000
# Epoch 34 Batch 700 Loss 0.0076
# Epoch 34 Batch 800 Loss 0.0004
# Epoch 34 Batch 900 Loss 0.0000
# Epoch 34 Batch 1000 Loss 0.0002
# Epoch 34 Batch 1100 Loss 0.0001
# Epoch 34 Batch 1200 Loss 0.0000
# Epoch 34 Loss 0.000491
# Time taken for 1 epoch 78.37008357048035 sec
#
# Epoch 35 Batch 0 Loss 0.0001
# Epoch 35 Batch 100 Loss 0.0000
# Epoch 35 Batch 200 Loss 0.0000
# Epoch 35 Batch 300 Loss 0.0000
# Epoch 35 Batch 400 Loss 0.0001
# Epoch 35 Batch 500 Loss 0.0000
# Epoch 35 Batch 600 Loss 0.0001
# Epoch 35 Batch 700 Loss 0.0045
# Epoch 35 Batch 800 Loss 0.0000
# Epoch 35 Batch 900 Loss 0.0000
# Epoch 35 Batch 1000 Loss 0.0000
# Epoch 35 Batch 1100 Loss 0.0000
# Epoch 35 Batch 1200 Loss 0.0000
# Epoch 35 Loss 0.000808
# Time taken for 1 epoch 78.58151292800903 sec
#
# Epoch 36 Batch 0 Loss 0.0000
# Epoch 36 Batch 100 Loss 0.0000
# Epoch 36 Batch 200 Loss 0.0000
# Epoch 36 Batch 300 Loss 0.0001
# Epoch 36 Batch 400 Loss 0.0000
# Epoch 36 Batch 500 Loss 0.0000
# Epoch 36 Batch 600 Loss 0.0000
# Epoch 36 Batch 700 Loss 0.0000
# Epoch 36 Batch 800 Loss 0.0000
# Epoch 36 Batch 900 Loss 0.0003
# Epoch 36 Batch 1000 Loss 0.0001
# Epoch 36 Batch 1100 Loss 0.0000
# Epoch 36 Batch 1200 Loss 0.0000
# Epoch 36 Loss 0.000606
# Time taken for 1 epoch 79.36612129211426 sec
#
# Epoch 37 Batch 0 Loss 0.0000
# Epoch 37 Batch 100 Loss 0.0004
# Epoch 37 Batch 200 Loss 0.0000
# Epoch 37 Batch 300 Loss 0.0000
# Epoch 37 Batch 400 Loss 0.0000
# Epoch 37 Batch 500 Loss 0.0000
# Epoch 37 Batch 600 Loss 0.0000
# Epoch 37 Batch 700 Loss 0.0000
# Epoch 37 Batch 800 Loss 0.0000
# Epoch 37 Batch 900 Loss 0.0000
# Epoch 37 Batch 1000 Loss 0.0001
# Epoch 37 Batch 1100 Loss 0.0000
# Epoch 37 Batch 1200 Loss 0.0001
# Epoch 37 Loss 0.000693
# Time taken for 1 epoch 80.0783953666687 sec
#
# Epoch 38 Batch 0 Loss 0.0000
# Epoch 38 Batch 100 Loss 0.0001
# Epoch 38 Batch 200 Loss 0.0000
# Epoch 38 Batch 300 Loss 0.0000
# Epoch 38 Batch 400 Loss 0.0000
# Epoch 38 Batch 500 Loss 0.0001
# Epoch 38 Batch 600 Loss 0.0000
# Epoch 38 Batch 700 Loss 0.0000
# Epoch 38 Batch 800 Loss 0.0000
# Epoch 38 Batch 900 Loss 0.0000
# Epoch 38 Batch 1000 Loss 0.0000
# Epoch 38 Batch 1100 Loss 0.0000
# Epoch 38 Batch 1200 Loss 0.0000
# Epoch 38 Loss 0.000369
# Time taken for 1 epoch 79.77826523780823 sec
#
# Epoch 39 Batch 0 Loss 0.0000
# Epoch 39 Batch 100 Loss 0.0000
# Epoch 39 Batch 200 Loss 0.0000
# Epoch 39 Batch 300 Loss 0.0000
# Epoch 39 Batch 400 Loss 0.0000
# Epoch 39 Batch 500 Loss 0.0000
# Epoch 39 Batch 600 Loss 0.0000
# Epoch 39 Batch 700 Loss 0.0000
# Epoch 39 Batch 800 Loss 0.0000
# Epoch 39 Batch 900 Loss 0.0000
# Epoch 39 Batch 1000 Loss 0.0000
# Epoch 39 Batch 1100 Loss 0.0391
# Epoch 39 Batch 1200 Loss 0.0001
# Epoch 39 Loss 0.000457
# Time taken for 1 epoch 80.84328198432922 sec
#
# Epoch 40 Batch 0 Loss 0.0000
# Epoch 40 Batch 100 Loss 0.0000
# Epoch 40 Batch 200 Loss 0.0000
# Epoch 40 Batch 300 Loss 0.0000
# Epoch 40 Batch 400 Loss 0.0000
# Epoch 40 Batch 500 Loss 0.0000
# Epoch 40 Batch 600 Loss 0.0000
# Epoch 40 Batch 700 Loss 0.0012
# Epoch 40 Batch 800 Loss 0.0000
# Epoch 40 Batch 900 Loss 0.0003
# Epoch 40 Batch 1000 Loss 0.0000
# Epoch 40 Batch 1100 Loss 0.0001
# Epoch 40 Batch 1200 Loss 0.0001
# Epoch 40 Loss 0.000745
# Time taken for 1 epoch 79.97963690757751 sec
#
# Epoch 41 Batch 0 Loss 0.0000
# Epoch 41 Batch 100 Loss 0.0000
# Epoch 41 Batch 200 Loss 0.0000
# Epoch 41 Batch 300 Loss 0.0000
# Epoch 41 Batch 400 Loss 0.0000
# Epoch 41 Batch 500 Loss 0.0000
# Epoch 41 Batch 600 Loss 0.0000
# Epoch 41 Batch 700 Loss 0.0000
# Epoch 41 Batch 800 Loss 0.0000
# Epoch 41 Batch 900 Loss 0.0009
# Epoch 41 Batch 1000 Loss 0.0000
# Epoch 41 Batch 1100 Loss 0.0000
# Epoch 41 Batch 1200 Loss 0.0000
# Epoch 41 Loss 0.000397
# Time taken for 1 epoch 79.38793969154358 sec
#
# Epoch 42 Batch 0 Loss 0.0000
# Epoch 42 Batch 100 Loss 0.0000
# Epoch 42 Batch 200 Loss 0.0000
# Epoch 42 Batch 300 Loss 0.0000
# Epoch 42 Batch 400 Loss 0.0000
# Epoch 42 Batch 500 Loss 0.0000
# Epoch 42 Batch 600 Loss 0.0006
# Epoch 42 Batch 700 Loss 0.0000
# Epoch 42 Batch 800 Loss 0.0000
# Epoch 42 Batch 900 Loss 0.0001
# Epoch 42 Batch 1000 Loss 0.0002
# Epoch 42 Batch 1100 Loss 0.0000
# Epoch 42 Batch 1200 Loss 0.0000
# Epoch 42 Loss 0.000360
# Time taken for 1 epoch 79.3716139793396 sec
#
# Epoch 43 Batch 0 Loss 0.0000
# Epoch 43 Batch 100 Loss 0.0002
# Epoch 43 Batch 200 Loss 0.0000
# Epoch 43 Batch 300 Loss 0.0000
# Epoch 43 Batch 400 Loss 0.0000
# Epoch 43 Batch 500 Loss 0.0000
# Epoch 43 Batch 600 Loss 0.0000
# Epoch 43 Batch 700 Loss 0.0000
# Epoch 43 Batch 800 Loss 0.0000
# Epoch 43 Batch 900 Loss 0.0000
# Epoch 43 Batch 1000 Loss 0.0000
# Epoch 43 Batch 1100 Loss 0.0001
# Epoch 43 Batch 1200 Loss 0.0000
# Epoch 43 Loss 0.000395
# Time taken for 1 epoch 80.86690592765808 sec
#
# Epoch 44 Batch 0 Loss 0.0000
# Epoch 44 Batch 100 Loss 0.0001
# Epoch 44 Batch 200 Loss 0.0000
# Epoch 44 Batch 300 Loss 0.0000
# Epoch 44 Batch 400 Loss 0.0000
# Epoch 44 Batch 500 Loss 0.0216
# Epoch 44 Batch 600 Loss 0.0000
# Epoch 44 Batch 700 Loss 0.0000
# Epoch 44 Batch 800 Loss 0.0000
# Epoch 44 Batch 900 Loss 0.0000
# Epoch 44 Batch 1000 Loss 0.0000
# Epoch 44 Batch 1100 Loss 0.0001
# Epoch 44 Batch 1200 Loss 0.0000
# Epoch 44 Loss 0.000496
# Time taken for 1 epoch 79.58780550956726 sec
#
# Epoch 45 Batch 0 Loss 0.0000
# Epoch 45 Batch 100 Loss 0.0000
# Epoch 45 Batch 200 Loss 0.0000
# Epoch 45 Batch 300 Loss 0.0005
# Epoch 45 Batch 400 Loss 0.0000
# Epoch 45 Batch 500 Loss 0.0000
# Epoch 45 Batch 600 Loss 0.0000
# Epoch 45 Batch 700 Loss 0.0000
# Epoch 45 Batch 800 Loss 0.0000
# Epoch 45 Batch 900 Loss 0.0000
# Epoch 45 Batch 1000 Loss 0.0000
# Epoch 45 Batch 1100 Loss 0.0000
# Epoch 45 Batch 1200 Loss 0.0001
# Epoch 45 Loss 0.000473
# Time taken for 1 epoch 79.89607858657837 sec
#
# Epoch 46 Batch 0 Loss 0.0000
# Epoch 46 Batch 100 Loss 0.0000
# Epoch 46 Batch 200 Loss 0.0000
# Epoch 46 Batch 300 Loss 0.0000
# Epoch 46 Batch 400 Loss 0.0000
# Epoch 46 Batch 500 Loss 0.0213
# Epoch 46 Batch 600 Loss 0.0000
# Epoch 46 Batch 700 Loss 0.0000
# Epoch 46 Batch 800 Loss 0.0047
# Epoch 46 Batch 900 Loss 0.0000
# Epoch 46 Batch 1000 Loss 0.0001
# Epoch 46 Batch 1100 Loss 0.0000
# Epoch 46 Batch 1200 Loss 0.0000
# Epoch 46 Loss 0.000446
# Time taken for 1 epoch 79.36441802978516 sec
#
# Epoch 47 Batch 0 Loss 0.0000
# Epoch 47 Batch 100 Loss 0.0000
# Epoch 47 Batch 200 Loss 0.0008
# Epoch 47 Batch 300 Loss 0.0000
# Epoch 47 Batch 400 Loss 0.0000
# Epoch 47 Batch 500 Loss 0.0201
# Epoch 47 Batch 600 Loss 0.0000
# Epoch 47 Batch 700 Loss 0.0000
# Epoch 47 Batch 800 Loss 0.0000
# Epoch 47 Batch 900 Loss 0.0000
# Epoch 47 Batch 1000 Loss 0.0000
# Epoch 47 Batch 1100 Loss 0.0000
# Epoch 47 Batch 1200 Loss 0.0000
# Epoch 47 Loss 0.000459
# Time taken for 1 epoch 80.51277947425842 sec
#
# Epoch 48 Batch 0 Loss 0.0000
# Epoch 48 Batch 100 Loss 0.0000
# Epoch 48 Batch 200 Loss 0.0001
# Epoch 48 Batch 300 Loss 0.0000
# Epoch 48 Batch 400 Loss 0.0000
# Epoch 48 Batch 500 Loss 0.0000
# Epoch 48 Batch 600 Loss 0.0000
# Epoch 48 Batch 700 Loss 0.0000
# Epoch 48 Batch 800 Loss 0.0000
# Epoch 48 Batch 900 Loss 0.0000
# Epoch 48 Batch 1000 Loss 0.0000
# Epoch 48 Batch 1100 Loss 0.0000
# Epoch 48 Batch 1200 Loss 0.0000
# Epoch 48 Loss 0.000428
# Time taken for 1 epoch 79.9078016281128 sec
#
# Epoch 49 Batch 0 Loss 0.0032
# Epoch 49 Batch 100 Loss 0.0000
# Epoch 49 Batch 200 Loss 0.0009
# Epoch 49 Batch 300 Loss 0.0000
# Epoch 49 Batch 400 Loss 0.0000
# Epoch 49 Batch 500 Loss 0.0000
# Epoch 49 Batch 600 Loss 0.0000
# Epoch 49 Batch 700 Loss 0.0000
# Epoch 49 Batch 800 Loss 0.0000
# Epoch 49 Batch 900 Loss 0.0000
# Epoch 49 Batch 1000 Loss 0.0000
# Epoch 49 Batch 1100 Loss 0.0004
# Epoch 49 Batch 1200 Loss 0.0000
# Epoch 49 Loss 0.000510
# Time taken for 1 epoch 80.70915985107422 sec
#
# Epoch 50 Batch 0 Loss 0.0000
# Epoch 50 Batch 100 Loss 0.0000
# Epoch 50 Batch 200 Loss 0.0005
# Epoch 50 Batch 300 Loss 0.0000
# Epoch 50 Batch 400 Loss 0.0000
# Epoch 50 Batch 500 Loss 0.0000
# Epoch 50 Batch 600 Loss 0.0000
# Epoch 50 Batch 700 Loss 0.0019
# Epoch 50 Batch 800 Loss 0.0000
# Epoch 50 Batch 900 Loss 0.0000
# Epoch 50 Batch 1000 Loss 0.0002
# Epoch 50 Batch 1100 Loss 0.0000
# Epoch 50 Batch 1200 Loss 0.0000
# Epoch 50 Loss 0.000469
# Time taken for 1 epoch 79.5765016078949 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
   attention_plot = np.zeros((max_length, attention_features_shape))

   hidden = decoder.reset_state(batch_size=1)
   temp_input = tf.expand_dims(load_image(image)[0], 0)
   img_tensor_val = image_features_extract_model(temp_input)
   img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

   features = encoder(img_tensor_val)
   dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
   result = []

   for i in range(max_length):
       predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
       attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
       predicted_id = tf.argmax(predictions[0]).numpy()
       result.append(tokenizer.index_word[predicted_id])

       if tokenizer.index_word[predicted_id] == '<end>':
           return result, attention_plot

       dec_input = tf.expand_dims([predicted_id], 0)
   attention_plot = attention_plot[:len(result), :]

   return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))
    fig = plt.figure(figsize=(10, 10))
    len_result = len(result)
    #print(result)
    #print(len(result))
    for l in range(1, len_result-1):
        #print(l)
        temp_att = np.resize(attention_plot[l], (8, 8))
        #print("hello" + str(l))
        ax = fig.add_subplot(len_result//2, len_result//2, l)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
rid = np.random.randint(0, len(img_name_val))
image = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\ffba62c94141.jpg'

# real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

# remove <start> and <end> from the real_caption
real_caption = 'scatter scattera'
first = real_caption.split(' ', 1)[1]

#remove "<unk>" in result
for i in result:
   if i=="<unk>":
       result.remove(i)

for i in real_caption:
   if i=="<unk>":
       real_caption.remove(i)

#remove <end> from result        
result_join = ' '.join(result)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = result

score = sentence_bleu(reference, candidate)
print(f"BELU score: {score*100}")

print ('Real Caption:', real_caption)
print ('Prediction Caption:', result_final)
plot_attention(image, result, attention_plot)
# Out:
# BELU score: 8.38826642100846e-153
# Real Caption: scatter scattera
# Prediction Caption: scatter scattera scatterb scatterc

# %%
rid = np.random.randint(0, len(img_name_val))
image = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\30a4e658c99b.jpg'

# real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

# remove <start> and <end> from the real_caption
real_caption = 'line linea'
first = real_caption.split(' ', 1)[1]

#remove "<unk>" in result
for i in result:
   if i=="<unk>":
       result.remove(i)

for i in real_caption:
   if i=="<unk>":
       real_caption.remove(i)

#remove <end> from result        
result_join = ' '.join(result)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = result

score = sentence_bleu(reference, candidate)
print(f"BELU score: {score*100}")

print ('Real Caption:', real_caption)
print ('Prediction Caption:', result_final)
plot_attention(image, result, attention_plot)
# Out:
# BELU score: 8.38826642100846e-153
# Real Caption: line linea
# Prediction Caption: line linea lineb linec

# %%
rid = np.random.randint(0, len(img_name_val))
image = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\869d37426a45.jpg'

# real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

# remove <start> and <end> from the real_caption
real_caption = 'line linea'
first = real_caption.split(' ', 1)[1]

#remove "<unk>" in result
for i in result:
   if i=="<unk>":
       result.remove(i)

for i in real_caption:
   if i=="<unk>":
       real_caption.remove(i)

#remove <end> from result        
result_join = ' '.join(result)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = result

score = sentence_bleu(reference, candidate)
print(f"BELU score: {score*100}")

print ('Real Caption:', real_caption)
print ('Prediction Caption:', result_final)
plot_attention(image, result, attention_plot)
# Out:
# BELU score: 8.38826642100846e-153
# Real Caption: line linea
# Prediction Caption: line linea lineb linec

# %%
rid = np.random.randint(0, len(img_name_val))
image = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\d7e90a8b9f9a.jpg'

# real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

# remove <start> and <end> from the real_caption
real_caption = 'scatter scattera scatterb scatterc'
first = real_caption.split(' ', 1)[1]

#remove "<unk>" in result
for i in result:
   if i=="<unk>":
       result.remove(i)

for i in real_caption:
   if i=="<unk>":
       real_caption.remove(i)

#remove <end> from result        
result_join = ' '.join(result)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = result

score = sentence_bleu(reference, candidate)
print(f"BELU score: {score*100}")

print ('Real Caption:', real_caption)
print ('Prediction Caption:', result_final)
plot_attention(image, result, attention_plot)
# Out:
# BELU score: 66.8740304976422
# Real Caption: scatter scattera scatterb scatterc
# Prediction Caption: scatter scattera scatterb scatterc

# %%
rid = np.random.randint(0, len(img_name_val))
image = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\d81d1c2dc898.jpg'

# real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

# remove <start> and <end> from the real_caption
real_caption = 'dot dota dotb dotc'
first = real_caption.split(' ', 1)[1]

#remove "<unk>" in result
for i in result:
   if i=="<unk>":
       result.remove(i)

for i in real_caption:
   if i=="<unk>":
       real_caption.remove(i)

#remove <end> from result        
result_join = ' '.join(result)
result_final = result_join.rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = result

score = sentence_bleu(reference, candidate)
print(f"BELU score: {score*100}")

print ('Real Caption:', real_caption)
print ('Prediction Caption:', result_final)
plot_attention(image, result, attention_plot)
# Out:
# BELU score: 0
# Real Caption: dot dota dotb dotc
# Prediction Caption: line linea lineb linec

# %%
#TODO
#EXTRACT INFO ABOUT SCATTER PLOTS
#EXTEND A PRETRAINED CAPTIONING MODEL TO CAPTION THOSE PLOTS
#DO ONE MODEL FOR EACH TYPE OF GRAPH
