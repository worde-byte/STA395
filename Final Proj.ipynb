# %%
from skimage import io
my_img = io.imread(r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images\ffba62c94141.jpg')
io.imshow(my_img)
io.show()

# %%
path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\images'
json_path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\annotations'
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torch.nn import functional
import json

bsize=256

img_names = os.listdir(path)
json_names = os.listdir(json_path)
i=0

images = np.empty(shape = (bsize, 3, 128, 128))
labels = np.chararray(bsize, itemsize=20)
for idx, name in enumerate(img_names):
    if (i==bsize):
        break
    img_name = path + '\\' + name
    json_name = json_path + '\\' + name
    json_name = json_name.replace(json_name[len(json_name) - 3:], 'json')
    # Use you favourite library to load the image
    image = plt.imread(img_name)
    image = torch.from_numpy(image)
    image = torch.unsqueeze(image, dim=0)
    image = torch.movedim(image, source=3, destination=1)
    image = functional.interpolate(image, size = (128,128))
    
    f = open(json_name)
    data = json.load(f)
    t = data['chart-type']
    f.close()
    
    #image_resized = functional.interpolate(image, size = (128,128))
    images[idx] = image
    labels[idx] = t
    i+=1
# Out:
# C:\Users\16032\AppData\Local\Temp\ipykernel_3668\1424981596.py:27: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  C:\b\abs_bao0hdcrdh\croot\pytorch_1675190257512\work\torch\csrc\utils\tensor_numpy.cpp:178.)
#   image = torch.from_numpy(image)

# %%
data['chart-type']
# Out:
# 'line'

# %%
#import json
#path = r'C:\Users\16032\Downloads\benetech-making-graphs-accessible\train\annotations'
#json_names = os.listdir(path)
#json_name = path + '\\' + json_names[0]
#f = open(json_name)
#data = json.load(f)

# %%
#labels

# %% [markdown]
# TODO
#
# Grab chart type
#
# resize images
#
# Set up neural net
